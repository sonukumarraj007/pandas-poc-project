# %%
import os
import seaborn as sns
import numpy as np
import pandas as pd
from numerize import numerize
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Read all files from the main Sales_Data directory

# %%
files = [file for file in os.listdir('Sales_Data/')]

for each_file in files:
    print(each_file)
# Out:
# Sales_December_2019.csv
# Sales_April_2019.csv
# Sales_February_2019.csv
# Sales_March_2019.csv
# Sales_August_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_January_2019.csv
# Sales_September_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv

# %%
all_month_data = pd.DataFrame()       # all_month_data is our empty dataframe

# %% [markdown]
# ## Concatenate each sales data into one complete dataset

# %%
for each_file in files:
    sales_data = pd.read_csv(f"./Sales_Data/{each_file}")
    all_month_data = pd.concat([all_month_data, sales_data])

# %%
all_month_data            # we will be working on this dataset
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       295665      Macbook Pro Laptop                1       1700
# 1       295666      LG Washing Machine                1      600.0
# 2       295667    USB-C Charging Cable                1      11.95
# 3       295668        27in FHD Monitor                1     149.99
# 4       295669    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 13617   222905  AAA Batteries (4-pack)                1       2.99
# 13618   222906        27in FHD Monitor                1     149.99
# 13619   222907    USB-C Charging Cable                1      11.95
# 13620   222908    USB-C Charging Cable                1      11.95
# 13621   222909  AAA Batteries (4-pack)                1       2.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 13617  06/07/19 19:02           795 Pine St, Boston, MA 02215
# 13618  06/01/19 19:29   495 North St, New York City, NY 10001
# 13619  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016
# 13620  06/26/19 18:35    916 Main St, San Francisco, CA 94016
# 13621  06/25/19 14:33          209 11th St, Atlanta, GA 30301
#
# [186850 rows x 6 columns]

# %%
all_month_data.shape
# Out:
# (186850, 6)

# %%
#save the complete dataset to a .csv file for further use 
all_month_data.to_csv('all_month_data.csv', index=False)

# %%
sales_data = pd.read_csv('all_month_data.csv')
sales_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
columns = sales_data.columns
columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# ### Some Data Wrangling Tasks.....

# %%
sales_data.isna()
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0          False    False             False       False       False
# 1          False    False             False       False       False
# 2          False    False             False       False       False
# 3          False    False             False       False       False
# 4          False    False             False       False       False
# ...          ...      ...               ...         ...         ...
# 186845     False    False             False       False       False
# 186846     False    False             False       False       False
# 186847     False    False             False       False       False
# 186848     False    False             False       False       False
# 186849     False    False             False       False       False
#
#         Purchase Address
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 186845             False
# 186846             False
# 186847             False
# 186848             False
# 186849             False
#
# [186850 rows x 6 columns]

# %%
sales_data.dropna()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# 1       12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2       12/12/19 18:21    277 Main St, New York City, NY 10001
# 3       12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4       12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...                ...                                     ...
# 186845  06/07/19 19:02           795 Pine St, Boston, MA 02215
# 186846  06/01/19 19:29   495 North St, New York City, NY 10001
# 186847  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016
# 186848  06/26/19 18:35    916 Main St, San Francisco, CA 94016
# 186849  06/25/19 14:33          209 11th St, Atlanta, GA 30301
#
# [186305 rows x 6 columns]

# %%
sales_data.shape
# Out:
# (186850, 6)

# %%
sales_data.dropna(axis="index", how="all", inplace=True)

# %%
sales_data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# 1       12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2       12/12/19 18:21    277 Main St, New York City, NY 10001
# 3       12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4       12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...                ...                                     ...
# 186845  06/07/19 19:02           795 Pine St, Boston, MA 02215
# 186846  06/01/19 19:29   495 North St, New York City, NY 10001
# 186847  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016
# 186848  06/26/19 18:35    916 Main St, San Francisco, CA 94016
# 186849  06/25/19 14:33          209 11th St, Atlanta, GA 30301
#
# [186305 rows x 6 columns]

# %%
sales_data.shape
# Out:
# (186305, 6)

# %%
sales_data.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 9.9+ MB

# %%
sales_data.loc[180125:180150, 'Product':'Price Each']
# Out:
#                            Product Quantity Ordered Price Each
# 180125    Lightning Charging Cable                1      14.95
# 180126      AAA Batteries (4-pack)                2       2.99
# 180127            27in FHD Monitor                1     149.99
# 180128       AA Batteries (4-pack)                1       3.84
# 180129  Bose SoundSport Headphones                1      99.99
# 180130            Wired Headphones                1      11.99
# 180131            27in FHD Monitor                1     149.99
# 180132  Bose SoundSport Headphones                1      99.99
# 180133    Apple Airpods Headphones                1        150
# 180134    Lightning Charging Cable                1      14.95
# 180135  Bose SoundSport Headphones                1      99.99
# 180136      AAA Batteries (4-pack)                1       2.99
# 180137    Apple Airpods Headphones                1        150
# 180138       AA Batteries (4-pack)                2       3.84
# 180139  Bose SoundSport Headphones                1      99.99
# 180140       AA Batteries (4-pack)                3       3.84
# 180141       AA Batteries (4-pack)                1       3.84
# 180142       AA Batteries (4-pack)                1       3.84
# 180143          Macbook Pro Laptop                1       1700
# 180144            27in FHD Monitor                1     149.99
# 180145            27in FHD Monitor                1     149.99
# 180146      AAA Batteries (4-pack)                1       2.99
# 180147      34in Ultrawide Monitor                1     379.99
# 180148       AA Batteries (4-pack)                3       3.84
# 180149    Lightning Charging Cable                1      14.95
# 180150    Lightning Charging Cable                1      14.95

# %%
sales_data.set_index('Order ID')
# Out:
#                          Product Quantity Ordered Price Each      Order Date  \
# Order ID
# 295665        Macbook Pro Laptop                1       1700  12/30/19 00:01
# 295666        LG Washing Machine                1      600.0  12/29/19 07:03
# 295667      USB-C Charging Cable                1      11.95  12/12/19 18:21
# 295668          27in FHD Monitor                1     149.99  12/22/19 15:13
# 295669      USB-C Charging Cable                1      11.95  12/18/19 12:38
# ...                          ...              ...        ...             ...
# 222905    AAA Batteries (4-pack)                1       2.99  06/07/19 19:02
# 222906          27in FHD Monitor                1     149.99  06/01/19 19:29
# 222907      USB-C Charging Cable                1      11.95  06/22/19 18:57
# 222908      USB-C Charging Cable                1      11.95  06/26/19 18:35
# 222909    AAA Batteries (4-pack)                1       2.99  06/25/19 14:33
#
#                                 Purchase Address
# Order ID
# 295665    136 Church St, New York City, NY 10001
# 295666       562 2nd St, New York City, NY 10001
# 295667      277 Main St, New York City, NY 10001
# 295668       410 6th St, San Francisco, CA 94016
# 295669             43 Hill St, Atlanta, GA 30301
# ...                                          ...
# 222905             795 Pine St, Boston, MA 02215
# 222906     495 North St, New York City, NY 10001
# 222907     319 Ridge St, San Francisco, CA 94016
# 222908      916 Main St, San Francisco, CA 94016
# 222909            209 11th St, Atlanta, GA 30301
#
# [186305 rows x 5 columns]

# %%
sales_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# # 1. What was the best month for sales? How much was earned that month?

# %%
#Create a new Column named 'Month' 
sales_data['Month'] = sales_data['Order Date'].str[0:2]
sales_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address Month
# 0  136 Church St, New York City, NY 10001    12
# 1     562 2nd St, New York City, NY 10001    12
# 2    277 Main St, New York City, NY 10001    12
# 3     410 6th St, San Francisco, CA 94016    12
# 4           43 Hill St, Atlanta, GA 30301    12

# %%
filt = sales_data['Quantity Ordered'] == 'Quantity Ordered'
new_df = sales_data.loc[-filt]

# %%
new_df.shape
# Out:
# (185950, 7)

# %%
new_df.loc[filt]
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Month]
# Index: []

# %%
new_df
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address Month
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001    12
# 1       12/29/19 07:03     562 2nd St, New York City, NY 10001    12
# 2       12/12/19 18:21    277 Main St, New York City, NY 10001    12
# 3       12/22/19 15:13     410 6th St, San Francisco, CA 94016    12
# 4       12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12
# ...                ...                                     ...   ...
# 186845  06/07/19 19:02           795 Pine St, Boston, MA 02215    06
# 186846  06/01/19 19:29   495 North St, New York City, NY 10001    06
# 186847  06/22/19 18:57   319 Ridge St, San Francisco, CA 94016    06
# 186848  06/26/19 18:35    916 Main St, San Francisco, CA 94016    06
# 186849  06/25/19 14:33          209 11th St, Atlanta, GA 30301    06
#
# [185950 rows x 7 columns]

# %%
new_df['Quantity Ordered'] = new_df['Quantity Ordered'].astype('int32')
# Out:
# <ipython-input-27-5ac78af9edc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Quantity Ordered'] = new_df['Quantity Ordered'].astype('int32')

# %%
new_df['Price Each'] = new_df['Price Each'].astype('float64')
# Out:
# <ipython-input-28-c3f592ef9cd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Price Each'] = new_df['Price Each'].astype('float64')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 10.6+ MB

# %%
new_df['Sales'] = (new_df['Quantity Ordered'] * new_df['Price Each'])
# Out:
# <ipython-input-30-1997d0637ff4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Sales'] = (new_df['Quantity Ordered'] * new_df['Price Each'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int32
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
#  7   Sales             185950 non-null  float64
# dtypes: float64(2), int32(1), object(5)
# memory usage: 12.1+ MB

# %%
new_df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95

# %%
def number_to_month(number):
    number = int(number)
    if number <= 12:
        month_name_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
        return month_name_list[number-1]
    else:
        print('Wrong Input')

# %%
def covert_to_short_number(number):
    return numerize.numerize(number, 2)

# %%
ans_df = new_df.groupby('Month').sum()

# %%
ans_df
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 01                10903  1.811768e+06  1.822257e+06
# 02                13449  2.188885e+06  2.202022e+06
# 03                17005  2.791208e+06  2.807100e+06
# 04                20558  3.367671e+06  3.390670e+06
# 05                18667  3.135125e+06  3.152607e+06
# 06                15253  2.562026e+06  2.577802e+06
# 07                16072  2.632540e+06  2.647776e+06
# 08                13448  2.230345e+06  2.244468e+06
# 09                13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
ans_df['Month Name'] = ans_df.index
ans_df['Month Name'] = ans_df['Month Name']

# %%
sns.set_style('darkgrid')
sns.barplot(ans_df['Month Name'], ans_df['Sales'])
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.style.use('fivethirtyeight')


month = ans_df.index
sales = ans_df['Sales']



plt.plot(month, sales, color="#444444", linewidth=2, marker='o')

plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales in USD')

plt.show()

# %% [markdown]
# # Thus, December was the best month for sales.
# #  and the money earned was more than 45M usd

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 2. Which city had the highest sales?

# %%
new_df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95

# %%
#Create new Column 'City'
new_df['City'] = new_df['Purchase Address'].apply(lambda x: x.split(',')[1])
new_df.head()
# Out:
# <ipython-input-42-5e82e2f7625d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['City'] = new_df['Purchase Address'].apply(lambda x: x.split(',')[1])
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
city_grp = new_df.groupby(['City'])

# %%
city_grp

# %%
ans_df2 = city_grp['Sales'].sum()
# ans_df2.rename('Units')

# %%
ans_df2
# Out:
# City
#  Atlanta          2.795499e+06
#  Austin           1.819582e+06
#  Boston           3.661642e+06
#  Dallas           2.767975e+06
#  Los Angeles      5.452571e+06
#  New York City    4.664317e+06
#  Portland         2.320491e+06
#  San Francisco    8.262204e+06
#  Seattle          2.747755e+06
# Name: Sales, dtype: float64

# %%
plt.style.use('seaborn')

plt.plot(ans_df2, color='#444444', marker='o', linewidth=2)

plt.title('City wise \n Sales')
plt.xlabel('City')
plt.xticks(rotation='45', size=13)
plt.yticks(size=13)
plt.ylabel('Sales in USD')

plt.show()

# %% [markdown]
# # San Francisco had the highest number of sales.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Which product was sold the most?

# %%
new_df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
ans_df3 = new_df.groupby(['Product']).sum()
ans_df3 = ans_df3.sort_values(by='Quantity Ordered')

# %%
ans_df3
# Out:
#                             Quantity Ordered  Price Each       Sales
# Product
# LG Dryer                                 646   387600.00   387600.00
# LG Washing Machine                       666   399600.00   399600.00
# Vareebadd Phone                         2068   826000.00   827200.00
# 20in Monitor                            4129   451068.99   454148.71
# ThinkPad Laptop                         4130  4127958.72  4129958.70
# Macbook Pro Laptop                      4728  8030800.00  8037600.00
# Flatscreen TV                           4819  1440000.00  1445700.00
# Google Phone                            5532  3315000.00  3319200.00
# 34in Ultrawide Monitor                  6199  2348718.19  2355558.01
# 27in 4K Gaming Monitor                  6244  2429637.70  2435097.56
# iPhone                                  6849  4789400.00  4794300.00
# 27in FHD Monitor                        7550  1125974.93  1132424.50
# Bose SoundSport Headphones             13457  1332366.75  1345565.43
# Apple Airpods Headphones               15661  2332350.00  2349150.00
# Wired Headphones                       20557   226395.18   246478.43
# Lightning Charging Cable               23217   323787.10   347094.15
# USB-C Charging Cable                   23975   261740.85   286501.25
# AA Batteries (4-pack)                  27635    79015.68   106118.40
# AAA Batteries (4-pack)                 31017    61716.59    92740.83

# %%
products = ans_df3.index
quantity = ans_df3['Quantity Ordered']

plt.style.use('seaborn')

plt.barh(products, quantity)
plt.xlabel('Units')
plt.xticks(size=15)
plt.yticks(size=15)

plt.show()

# %% [markdown]
# # More than 30k units of AAA Batteries (4-pack) were sold, making them the highest unit of product sold.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 4. Which sold product was the most expensive?

# %%
ans_df3 = ans_df3.sort_values(by='Sales')

# %%
products = ans_df3.index
sales = ans_df3['Sales']

plt.style.use('seaborn')

plt.barh(products, sales)
plt.xlabel('Sales in USD')
plt.xticks(size=10)
plt.yticks(size=10)

plt.show()

# %% [markdown]
# # Out of the total products sold, Macbook Pro Laptop was the most expensive.

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 5. In which city is Macbook pro laptop sold the most?

# %%
new_df.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address Month    Sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001    12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001    12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001    12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016    12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301    12    11.95
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
ans_df4 = new_df.groupby(['City'])

# %%
mac_users = ans_df4['Product'].apply(lambda x : x.str.contains('Macbook Pro Laptop').sum())
mac_users
# Out:
# City
#  Atlanta           379
#  Austin            251
#  Boston            478
#  Dallas            382
#  Los Angeles       751
#  New York City     656
#  Portland          337
#  San Francisco    1134
#  Seattle           356
# Name: Product, dtype: int64

# %%
mac_users.sort_values
# Out:
# <bound method Series.sort_values of City
#  Atlanta           379
#  Austin            251
#  Boston            478
#  Dallas            382
#  Los Angeles       751
#  New York City     656
#  Portland          337
#  San Francisco    1134
#  Seattle           356
# Name: Product, dtype: int64>

# %%
plt.style.use('seaborn')

plt.bar(mac_users.index, mac_users, width=0.5)

plt.title('MacBooks Sales \n Across the US')
plt.xlabel('City')
plt.ylabel('Units Sold')

plt.xticks(rotation='45', size=13)
plt.yticks(size=13)

plt.show()

# %% [markdown]
# # SF is the city where MacBooks were sold the most.
